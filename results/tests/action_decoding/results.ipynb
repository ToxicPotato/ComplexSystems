# %%
import pandas as pd
import glob

files = sorted(glob.glob('run_ca*.csv'))
df = pd.concat((pd.read_csv(f) for f in files), ignore_index=True)

print(f"Loaded {len(files)} files, total rows = {len(df)}")
df.head()
# Out:
# Loaded 3 files, total rows = 2711
#             run_id  episode_index  step_count     time_start       time_end  \
# 0  20250519_014730              0           0  617874.108511  617874.109183
# 1  20250519_014730              0           1  617874.128627  617874.129146
# 2  20250519_014730              0           2  617874.148956  617874.149448
# 3  20250519_014730              0           3  617874.169733  617874.170116
# 4  20250519_014730              0           4  617874.190718  617874.191229
#
#    time_delta_ms                                  observation_state  \
# 0         0.6716  [ 0.02400044 -0.01379585  0.01166505 -0.00974665]
# 1         0.5195  [ 0.02372453 -0.20908312  0.01147011  0.2865938 ]
# 2         0.4912  [ 0.01954286 -0.01412662  0.01720199 -0.0024496 ]
# 3         0.3836  [ 0.01926033 -0.209491    0.017153    0.29561076]
# 4         0.5104  [ 0.01507051 -0.01461773  0.02306521  0.00838658]
#
#    action_taken  reward_received  terminated  bits_per_value  row_length  \
# 0             0              1.0       False               8          64
# 1             1              1.0       False               8          64
# 2             0              1.0       False               8          64
# 3             1              1.0       False               8          64
# 4             1              1.0       False               8          64
#
#    neighborhood_radius  num_ca_ticks  boundary_condition action_decoding  \
# 0                    1            10                 NaN          center
# 1                    1            10                 NaN          center
# 2                    1            10                 NaN          center
# 3                    1            10                 NaN          center
# 4                    1            10                 NaN          center
#
#    rule_index
# 0         118
# 1         118
# 2         118
# 3         118
# 4         118
